# %% [markdown]
# ![](../img/330-banner.png)

# %% [markdown]
# # (Optional)<br>Lecture 25: Combining Multiple Tables
#
# UBC 2025-26
#
# <br>
#
# This lecture is optional and will **not be included in the exam**.
#
# <br>

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import Ridge, LogisticRegression, SGDClassifier, SGDRegressor
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.dummy import DummyClassifier, DummyRegressor
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate

# %% [markdown]
# - Take a look at the [Formula 1 race data set](https://www.kaggle.com/cjgdev/formula-1-race-data-19502017) from Kaggle.
# - The dataset contains **multiple CSV files**.
# - Let's read in one of them:

# %%
racing_results_df = pd.read_csv("../data/formula-1-race/results.csv", index_col=0)
racing_results_df
# Out:
#           raceId  driverId  constructorId  number  grid  position  \
# resultId
# 1             18         1              1    22.0     1       1.0
# 2             18         2              2     3.0     5       2.0
# 3             18         3              3     7.0     7       3.0
# 4             18         4              4     5.0    11       4.0
# 5             18         5              1    23.0     3       5.0
# ...          ...       ...            ...     ...   ...       ...
# 23777        988       842              5    10.0    17      16.0
# 23778        988       828             15     9.0    19      17.0
# 23779        988       840              3    18.0    15      18.0
# 23780        988       832              4    55.0    12       NaN
# 23781        988       817              9     3.0     4       NaN
#
#          positionText  positionOrder  points  laps     time  milliseconds  \
# resultId
# 1                   1              1    10.0    58  34:50.6     5690616.0
# 2                   2              2     8.0    58    5.478     5696094.0
# 3                   3              3     6.0    58    8.163     5698779.0
# 4                   4              4     5.0    58   17.181     5707797.0
# 5                   5              5     4.0    58   18.014     5708630.0
# ...               ...            ...     ...   ...      ...           ...
# 23777              16             16     0.0    54      NaN           NaN
# 23778              17             17     0.0    54      NaN           NaN
# 23779              18             18     0.0    54      NaN           NaN
# 23780               R             19     0.0    31      NaN           NaN
# 23781               R             20     0.0    20      NaN           NaN
#
#           fastestLap  rank fastestLapTime fastestLapSpeed  statusId
# resultId
# 1               39.0   2.0        01:27.5           218.3         1
# 2               41.0   3.0        01:27.7         217.586         1
# 3               41.0   5.0        01:28.1         216.719         1
# 4               58.0   7.0        01:28.6         215.464         1
# 5               43.0   1.0        01:27.4         218.385         1
# ...              ...   ...            ...             ...       ...
# 23777           33.0  16.0        01:43.8         192.542        11
# 23778           36.0  15.0        01:43.6         193.057        11
# 23779           52.0   6.0        01:42.3         195.402        11
# 23780           26.0  14.0        01:43.4          193.41        36
# 23781           13.0  12.0        01:42.8         194.579         9
#
# [23777 rows x 17 columns]

# %% [markdown]
# - Let's say we want to predict the `milliseconds` column, namely the total length of time it takes a driver to finish a race.
# - In that case, we should not have access to most of these other columns.
# - But we would have the `raceId` and `driverId`:

# %%
racing_results_df_subset = racing_results_df.dropna(
    subset=["milliseconds"])[['raceId', 'driverId', 'milliseconds']]
racing_results_df_subset
# Out:
#           raceId  driverId  milliseconds
# resultId
# 1             18         1     5690616.0
# 2             18         2     5696094.0
# 3             18         3     5698779.0
# 4             18         4     5707797.0
# 5             18         5     5708630.0
# ...          ...       ...           ...
# 23765        988         8     5699448.0
# 23766        988       830     5700331.0
# 23767        988       807     5739775.0
# 23768        988       815     5746124.0
# 23769        988       839     5752973.0
#
# [6003 rows x 3 columns]

# %%
racing_train, racing_test = train_test_split(racing_results_df_subset, random_state=123)

# %% [markdown]
# We can try some baselines based on the ID values themselves, although:

# %%
pd.DataFrame(cross_validate(DummyRegressor(), racing_train[["raceId", "driverId"]], 
                            racing_train["milliseconds"], return_train_score=True, cv=20)).mean()
# Out:
# fit_time       0.000965
# score_time     0.000557
# test_score    -0.002014
# train_score    0.000000
# dtype: float64

# %%
lr = make_pipeline(OneHotEncoder(handle_unknown='ignore'), Ridge())
pd.DataFrame(cross_validate(lr, racing_train[["raceId", "driverId"]], 
                            racing_train["milliseconds"], return_train_score=True, cv=20)).mean()
# Out:
# fit_time       0.014059
# score_time     0.002718
# test_score     0.949380
# train_score    0.981957
# dtype: float64

# %% [markdown]
# That is actually pretty good *facepalm*.

# %% [markdown]
# But what if we want to predict for a **_new_ race track** or a **_new_ driver**?

# %% [markdown]
# - Enter the other tables:

# %%
racing_drivers_df = pd.read_csv("../data/formula-1-race/drivers.csv", 
                                encoding='latin-1', index_col=0, 
                                dayfirst=True, parse_dates=['dob'])
racing_drivers_df
# Out:
#                 driverRef  number code  forename     surname         dob  \
# driverId
# 1                hamilton    44.0  HAM     Lewis    Hamilton  07/01/1985
# 2                heidfeld     NaN  HEI      Nick    Heidfeld  10/05/1977
# 3                 rosberg     6.0  ROS      Nico     Rosberg  27/06/1985
# 4                  alonso    14.0  ALO  Fernando      Alonso  29/07/1981
# 5              kovalainen     NaN  KOV    Heikki  Kovalainen  19/10/1981
# ...                   ...     ...  ...       ...         ...         ...
# 838             vandoorne     2.0  VAN   Stoffel   Vandoorne  26/03/1992
# 839                  ocon    31.0  OCO   Esteban        Ocon  17/09/1996
# 840                stroll    18.0  STR     Lance      Stroll  29/10/1998
# 841            giovinazzi    36.0  GIO   Antonio  Giovinazzi  14/12/1993
# 843       brendon_hartley    39.0  HAR   Brendon     Hartley  10/11/1989
#
#             nationality                                              url
# driverId
# 1               British      http://en.wikipedia.org/wiki/Lewis_Hamilton
# 2                German       http://en.wikipedia.org/wiki/Nick_Heidfeld
# 3                German        http://en.wikipedia.org/wiki/Nico_Rosberg
# 4               Spanish     http://en.wikipedia.org/wiki/Fernando_Alonso
# 5               Finnish   http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ...                 ...                                              ...
# 838             Belgian   http://en.wikipedia.org/wiki/Stoffel_Vandoorne
# 839              French        http://en.wikipedia.org/wiki/Esteban_Ocon
# 840            Canadian        http://en.wikipedia.org/wiki/Lance_Stroll
# 841             Italian  http://en.wikipedia.org/wiki/Antonio_Giovinazzi
# 843       New Zealander     http://en.wikipedia.org/wiki/Brendon_Hartley
#
# [842 rows x 8 columns]

# %% [markdown]
# - Can we use the driver's **nationality** and **age** as features?
# - `pd.merge` can take care of this for us.

# %%
merged_df = pd.merge(racing_results_df_subset, racing_drivers_df, on="driverId")
merged_df
# Out:
#       raceId  driverId  milliseconds       driverRef  number code  forename  \
# 0         18         1     5690616.0        hamilton    44.0  HAM     Lewis
# 1         18         2     5696094.0        heidfeld     NaN  HEI      Nick
# 2         18         3     5698779.0         rosberg     6.0  ROS      Nico
# 3         18         4     5707797.0          alonso    14.0  ALO  Fernando
# 4         18         5     5708630.0      kovalainen     NaN  KOV    Heikki
# ...      ...       ...           ...             ...     ...  ...       ...
# 5998     988         8     5699448.0       raikkonen     7.0  RAI      Kimi
# 5999     988       830     5700331.0  max_verstappen    33.0  VER       Max
# 6000     988       807     5739775.0      hulkenberg    27.0  HUL      Nico
# 6001     988       815     5746124.0           perez    11.0  PER    Sergio
# 6002     988       839     5752973.0            ocon    31.0  OCO   Esteban
#
#           surname         dob nationality  \
# 0        Hamilton  07/01/1985     British
# 1        Heidfeld  10/05/1977      German
# 2         Rosberg  27/06/1985      German
# 3          Alonso  29/07/1981     Spanish
# 4      Kovalainen  19/10/1981     Finnish
# ...           ...         ...         ...
# 5998  RÌ_ikkÌ¦nen  17/10/1979     Finnish
# 5999   Verstappen  30/09/1997       Dutch
# 6000  HÌ_lkenberg  19/08/1987      German
# 6001       PÌ©rez  26/01/1990     Mexican
# 6002         Ocon  17/09/1996      French
#
#                                                     url
# 0           http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1            http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2             http://en.wikipedia.org/wiki/Nico_Rosberg
# 3          http://en.wikipedia.org/wiki/Fernando_Alonso
# 4        http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ...                                                 ...
# 5998  http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C...
# 5999        http://en.wikipedia.org/wiki/Max_Verstappen
# 6000  http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg
# 6001     http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez
# 6002          http://en.wikipedia.org/wiki/Esteban_Ocon
#
# [6003 rows x 11 columns]

# %% [markdown]
# - The `on` keyword told it which column to use to match up the rows of the two dataframes.
# - Note that the first 5 rows have the same `driverId`, so they pulled the same data from `racing_drivers_df`.
# - Now we could keep only the columns we plan to encode:

# %%
merged_df_subset = merged_df[['raceId', 'driverId', 'milliseconds', 'dob', 'nationality']]
merged_df_subset
# Out:
#       raceId  driverId  milliseconds         dob nationality
# 0         18         1     5690616.0  07/01/1985     British
# 1         18         2     5696094.0  10/05/1977      German
# 2         18         3     5698779.0  27/06/1985      German
# 3         18         4     5707797.0  29/07/1981     Spanish
# 4         18         5     5708630.0  19/10/1981     Finnish
# ...      ...       ...           ...         ...         ...
# 5998     988         8     5699448.0  17/10/1979     Finnish
# 5999     988       830     5700331.0  30/09/1997       Dutch
# 6000     988       807     5739775.0  19/08/1987      German
# 6001     988       815     5746124.0  26/01/1990     Mexican
# 6002     988       839     5752973.0  17/09/1996      French
#
# [6003 rows x 5 columns]

# %% [markdown]
# Now we can process the `dob` column to get age:

# %%
dob = pd.to_datetime(merged_df_subset["dob"], format="mixed")
ages = (pd.Timestamp('2017-01-01') - dob).apply(lambda x: x.total_seconds()/3600/24/365)  # A bad estimate of age just for illustration
merged_df_age = merged_df_subset.assign(age=ages)
merged_df_age
# Out:
#       raceId  driverId  milliseconds         dob nationality        age
# 0         18         1     5690616.0  07/01/1985     British  31.526027
# 1         18         2     5696094.0  10/05/1977      German  39.268493
# 2         18         3     5698779.0  27/06/1985      German  31.536986
# 3         18         4     5707797.0  29/07/1981     Spanish  35.452055
# 4         18         5     5708630.0  19/10/1981     Finnish  35.227397
# ...      ...       ...           ...         ...         ...        ...
# 5998     988         8     5699448.0  17/10/1979     Finnish  37.235616
# 5999     988       830     5700331.0  30/09/1997       Dutch  19.268493
# 6000     988       807     5739775.0  19/08/1987      German  29.391781
# 6001     988       815     5746124.0  26/01/1990     Mexican  26.950685
# 6002     988       839     5752973.0  17/09/1996      French  20.304110
#
# [6003 rows x 6 columns]

# %% [markdown]
# - So far we got information for each driver.
# - Likewise, we can get information about the races, and use those as well.

# %%
racing_races_df = pd.read_csv("../data/formula-1-race/races.csv", encoding='latin-1', index_col=0)
racing_races_df
# Out:
#         year  round  circuitId                      name        date  \
# raceId
# 1       2009      1          1     Australian Grand Prix  2009-03-29
# 2       2009      2          2      Malaysian Grand Prix  2009-04-05
# 3       2009      3         17        Chinese Grand Prix  2009-04-19
# 4       2009      4          3        Bahrain Grand Prix  2009-04-26
# 5       2009      5          4        Spanish Grand Prix  2009-05-10
# ...      ...    ...        ...                       ...         ...
# 1005    2018     17         22       Japanese Grand Prix  2018-10-07
# 1006    2018     18         69  United States Grand Prix  2018-10-21
# 1007    2018     19         32        Mexican Grand Prix  2018-10-28
# 1008    2018     20         18      Brazilian Grand Prix  2018-11-11
# 1009    2018     21         24      Abu Dhabi Grand Prix  2018-11-25
#
#             time                                                url
# raceId
# 1       06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 2       09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 3       07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 4       12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 5       12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...
# ...          ...                                                ...
# 1005    05:00:00  http://en.wikipedia.org/wiki/2018_Japanese_Gra...
# 1006    19:00:00  http://en.wikipedia.org/wiki/2018_United_State...
# 1007    19:00:00  http://en.wikipedia.org/wiki/2018_Mexican_Gran...
# 1008    16:00:00  http://en.wikipedia.org/wiki/2018_Brazilian_Gr...
# 1009    13:00:00  http://en.wikipedia.org/wiki/2018_Abu_Dhabi_Gr...
#
# [997 rows x 7 columns]

# %% [markdown]
# Etc.

# %% [markdown]
# - For those who have taken CPSC 304 or some have other database training, you'll recognize this type of multi-table situation, with foreign keys connecting the tables.
# - `pd.merge` supports several types of joins, see the documentation:

# %%
merged_df_full = pd.merge(merged_df_age, racing_races_df, on="raceId")
merged_df_full.head()
# Out:
#    raceId  driverId  milliseconds         dob nationality        age  year  \
# 0      18         1     5690616.0  07/01/1985     British  31.526027  2008
# 1      18         2     5696094.0  10/05/1977      German  39.268493  2008
# 2      18         3     5698779.0  27/06/1985      German  31.536986  2008
# 3      18         4     5707797.0  29/07/1981     Spanish  35.452055  2008
# 4      18         5     5708630.0  19/10/1981     Finnish  35.227397  2008
#
#    round  circuitId                   name        date      time  \
# 0      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 1      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 2      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 3      1          1  Australian Grand Prix  2008-03-16  04:30:00
# 4      1          1  Australian Grand Prix  2008-03-16  04:30:00
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/2008_Australian_G...
# 1  http://en.wikipedia.org/wiki/2008_Australian_G...
# 2  http://en.wikipedia.org/wiki/2008_Australian_G...
# 3  http://en.wikipedia.org/wiki/2008_Australian_G...
# 4  http://en.wikipedia.org/wiki/2008_Australian_G...

# %% [markdown]
# Maybe we just take the circuit ID:

# %%
merged_df_final = merged_df_full.drop(
    columns=["dob", "name", "date", "time", "url", "raceId", "driverId"])
merged_df_final
# Out:
#       milliseconds nationality        age  year  round  circuitId
# 0        5690616.0     British  31.526027  2008      1          1
# 1        5696094.0      German  39.268493  2008      1          1
# 2        5698779.0      German  31.536986  2008      1          1
# 3        5707797.0     Spanish  35.452055  2008      1          1
# 4        5708630.0     Finnish  35.227397  2008      1          1
# ...            ...         ...        ...   ...    ...        ...
# 5998     5699448.0     Finnish  37.235616  2017     20         24
# 5999     5700331.0       Dutch  19.268493  2017     20         24
# 6000     5739775.0      German  29.391781  2017     20         24
# 6001     5746124.0     Mexican  26.950685  2017     20         24
# 6002     5752973.0      French  20.304110  2017     20         24
#
# [6003 rows x 6 columns]

# %%
categorical_features = ["nationality", "round", "circuitId"]
numeric_features = ["age", "year"]

preprocessing = make_column_transformer(
    (OneHotEncoder(handle_unknown='ignore'), categorical_features),
    (StandardScaler(), numeric_features)
)
lr = make_pipeline(preprocessing, Ridge())
# pd.DataFrame(cross_validate(lr, merged_df_final.drop(columns=["milliseconds"]), 
#                             merged_df_final["milliseconds"], return_train_score=True, cv=20)).mean()

# %%
lr.fit(merged_df_final.drop(columns=["milliseconds"]), merged_df_final["milliseconds"]);

# %% [markdown]
# This new model can be used even for new drivers and races because it's based on features we got from these other tables.

# %%
# preprocessing.fit(merged_df_final)
ohe_columns = list(
    preprocessing.named_transformers_['onehotencoder']
    .get_feature_names_out(categorical_features))
new_columns = ohe_columns + numeric_features
lr_coefs = pd.DataFrame(data=lr[1].coef_, index=new_columns, columns=["Coefficient"])
lr_coefs
# Out:
#                          Coefficient
# nationality_American    9.390199e+05
# nationality_Argentine   4.770765e+05
# nationality_Australian  1.968886e+04
# nationality_Austrian   -4.021459e+05
# nationality_Belgian    -3.579882e+05
# ...                              ...
# circuitId_70            7.455358e+04
# circuitId_71            3.066543e+05
# circuitId_73            1.343838e+06
# age                     1.382989e+05
# year                   -6.846658e+05
#
# [123 rows x 1 columns]
